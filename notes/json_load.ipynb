# %% [markdown]
# # **Demo -** Loading JSON Document in Jupyter Notebook
#
# ## Richie Nyce
#
# ### 8/25/2025
# ---

# %% [markdown]
# 1. Import the JSON Library

# %%
import json as js

# %% [markdown]
# 2. Locate the JSON file on your computer and assign it to any variable.
# `path = r"my_path"`

# %%
path = r'/Users/richardnyce/School/!-2025/2025 Fall/Data in EMAT/002-Instagram LIKES/Instagram Data/ads_information/instagram_ads_and_businesses/advertisers_using_your_activity_or_information.json'

# %% [markdown]
# 3. Open the path using the syntax below.
#    - Opening as a read-only mode.
#    - Assigning the open to a variable.

# %%
with open(path, "r") as f:
    data = js.load(f)

# %% [markdown]
# 4. Print DATA to test and make sure everything is working.

# %%
print(data)
# Out:
# {'ig_custom_audiences_all_types': [{'advertiser_name': 'Universal Music France', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'Southern California Edison', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'Ford Motor Company', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'Zulily', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'X-VIN', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'My Medic', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': False, 'has_in_person_store_visit': False}, {'advertiser_name': 'Sunda
# ...
